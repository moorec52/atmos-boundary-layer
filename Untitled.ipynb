# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cues = pd.read_pickle('data/CUES_L1_Temp_Rad_Wind_Mar-Apr2017.pkl')

# %%
cues.columns
# Out:
# Index(['Platform relative humidity; platform temperature/relative humidity; (percent)',
#        'Platform temperature; platform temperature/relative humidity; (degrees Celsius)',
#        'snow temperature 1; thermister 1; (degrees Celsius)',
#        'snow temperature 2; thermister 2; (degrees Celsius)',
#        'snow temperature 3; thermister 3; (degrees Celsius)',
#        'snow temperature 4; thermister 4; (degrees Celsius)',
#        'snow temperature 5; thermister 5; (degrees Celsius)',
#        'snow temperature 6; thermister 6; (degrees Celsius)',
#        'snow temperature 7; thermister 7; (degrees Celsius)',
#        'snow temperature 8; thermister 8; (degrees Celsius)',
#        'soil temperature @ 0cm; soil temp at 0cm  center; (degrees Celsius)',
#        'soil temperature @ 10cm; soil temp at 10cm  center; (degrees Celsius)',
#        'soil temperature @ 20cm; soil temp at 20cm  center; (degrees Celsius)',
#        'soil temperature @ 30cm; soil temp at 30cm  center; (degrees Celsius)',
#        'soil temperature @ 40cm; soil temp at 40cm  center; (degrees Celsius)',
#        'soil temperature @ 50cm; soil temp at 50cm  center; (degrees Celsius)',
#        'soil temperature @ 60cm; soil temp at 60cm  center; (degrees Celsius)',
#        'soil temperature @ 70cm; soil temp at 70cm  center; (degrees Celsius)',
#        'soil temperature @ 80cm; soil temp at 80cm  center; (degrees Celsius)',
#        'soil temperature @ 90cm; soil temp at 90cm  center; (degrees Celsius)',
#        'CO2 concentration; bunker air temperature  atmospheric pressure and CO2 sensor; (parts per million)',
#        'bunker temperature; bunker air temperature  atmospheric pressure and CO2 sensor; (degrees Celsius)',
#        'bunker air pressure  not adjusted; bunker air temperature  atmospheric pressure and CO2 sensor; (millibars)',
#        'soil temp at 0cm  north; soil thermistor at 0cm  north; (deg C)',
#        'soil temp at 10cm  north; soil thermistor at 10cm  north; (deg C)',
#        'soil temp at 20cm  north; soil thermistor at 20cm  north; (deg C)',
#        'soil temp at 30cm  north; soil thermistor at 30cm  north; (deg C)',
#        'soil temp at 40cm  north; soil thermistor at 40cm  north; (deg C)',
#        'soil temp at 50cm  north; soil thermistor at 50cm  north; (deg C)',
#        'soil temp at 60cm  north; soil thermistor at 60cm  north; (deg C)',
#        'soil temp at 70cm  north; soil thermistor at 70cm  north; (deg C)',
#        'soil temp at 80cm  north; soil thermistor at 80cm  north; (deg C)',
#        'soil temp at 90cm  north; soil thermistor at 90cm  north; (deg C)',
#        'soil temp at 0cm  south; soil thermistor at 0cm  south; (deg C)',
#        'soil temp at 10cm  south; soil thermistor at 10cm  south; (deg C)',
#        'soil temp at 20cm  south; soil thermistor at 20cm  south; (deg C)',
#        'soil temp at 30cm  south; soil thermistor at 30cm  south; (deg C)',
#        'soil temp at 40cm  south; soil thermistor at 40cm  south; (deg C)',
#        'soil temp at 50cm  south; soil thermistor at 50cm  south; (deg C)',
#        'soil temp at 60cm  south; soil thermistor at 60cm  south; (deg C)',
#        'soil temp at 70cm  south; soil thermistor at 70cm  south; (deg C)',
#        'soil temp at 80cm  south; soil thermistor at 80cm  south; (deg C)',
#        'soil temp at 90cm  south; soil thermistor at 90cm  south; (deg C)',
#        'snow surface temperature; Apogee SI-111 thermal radiometer; (Celsius)',
#        'thermal IR temp sensor voltage; Apogee SI-111 thermal radiometer; (mV)',
#        'thermal IR temp sensor case temp; Apogee SI-111 thermal radiometer; (Celsius)',
#        'upward looking solar radiation; uplooking Eppley Lab precision spectral pyranometer; (Watts/meter^2)',
#        'upward looking near-IR radiation; uplooking Eppley Lab precision spectral pyranometer w/ IR filter; (Watts/meter^2)',
#        'downward looking solar radiation; downlooking Eppley Lab precision spectral pyranometer; (Watts/meter^2)',
#        'downward looking clear solar  Bunker; downlooking Eppley Lab precision spectral pyranometer; (Watts/meter^2)',
#        'downward looking near-IR radiation; downlooking Eppley Lab precision spectral pyranometer w/ IR filter; (Watts/meter^2)',
#        'downward looking red solar  Bunker; downlooking Eppley Lab precision spectral pyranometer w/ IR filter; (Watts/meter^2)',
#        'upward looking longwave radiation; uplooking Eppley lab precision infrared long wave radiometer; (Watts/meter^2)',
#        'Upward Looking longwave voltage; uplooking Eppley lab precision infrared long wave radiometer; (millivolts)',
#        'PIR case temp; uplooking Eppley lab precision infrared long wave radiometer; (Kelvin)',
#        'upward looking solar radiation; uplooking Sunshine pyranometer  direct and diffuse; (Watts/meter^2)',
#        'upward looking diffuse radiation; uplooking Sunshine pyranometer  direct and diffuse; (Watts/meter^2)',
#        'SUN flag; uplooking Sunshine pyranometer  direct and diffuse; (bit)',
#        'upper mast wind speed; upper RM Young bird; (meters/second)',
#        'upper mast wind direction; upper RM Young bird; (degrees)',
#        'upper mast std deviation; upper RM Young bird; (meters/second)',
#        'sonic wind speed; Sonic anemometer; (meters/second)',
#        'sonic wind direction; Sonic anemometer; (degrees)',
#        'Sonic wind direction  standard deviation; Sonic anemometer; (degrees)',
#        'wind quality; ws600 wind quality; (percent)'],
#       dtype='object')

# %%
cues['sonic wind direction; Sonic anemometer; (degrees)'].plot()
cues['Sonic wind direction  standard deviation; Sonic anemometer; (degrees)'].plot()
cues['wind quality; ws600 wind quality; (percent)'].plot()
cues['sonic wind speed; Sonic anemometer; (meters/second)'].plot()

# %%
startdate = pd.Timestamp('2017-04-21')
enddate = pd.Timestamp('2017-04-22')

fig, ax = plt.subplots(2,1,figsize=(10,7))
# Snow surface temp
ax[0].set_title('Snow Surface Temperature')
cues['snow surface temperature; Apogee SI-111 thermal radiometer; (Celsius)'].plot(ax=ax[0],
                                                                                  c='k')

# Air temp
ax[1].set_title('Air Temperature')
cues['Platform temperature; platform temperature/relative humidity; (degrees Celsius)'].plot(ax=ax[1],
                                                                                            c='k')


# finish up plot labels, axes, etc
for _ax in ax:
    _ax.set_xlim((startdate,enddate))
    _ax.set_ylim((-15,15))
    _ax.set_ylabel('Temperature [$C\degree$]')
    _ax.set_xlabel('Date, Time')
    _ax.grid(axis='x',color='lightgrey', linestyle=':', linewidth=1)
    _ax.axhline(0,color='k', linestyle='--', linewidth=1, zorder=-99)

fig.autofmt_xdate(rotation=0, ha='center')
plt.tight_layout()

# %%
precip = pd.read_pickle('data/CUES_L1_Precip_Mar-Apr2017.pkl')

# %%
precip['snow depth  platform; ultrasonic depth pinger on platform; (cm)'].plot()
precip['snow depth  remote boom; ultrasonic depth pinger on remote boom; (cm)'].plot()
precip['snow depth  wind mast; ultrasonic depth pinger on moveable wind mast; (cm)'].plot()
plt.legend()

# %%
plt.figure(figsize=(5,5))

plt.scatter(x=cues['snow surface temperature; Apogee SI-111 thermal radiometer; (Celsius)'],
           y=cues['Platform temperature; platform temperature/relative humidity; (degrees Celsius)'],
           marker='.',s=1,alpha=0.1,c='k')

plt.xlim((-30,15))
plt.ylim((-30,15))
plt.plot([-50,50],[-50,50],':',color='red')
